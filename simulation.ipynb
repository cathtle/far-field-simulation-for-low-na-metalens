# %%
print("✅ Notebook 环境测试成功！")

import sys
print(f"Python 版本: {sys.version}")

# 简单数学测试
result = sum(range(1, 101))
print(f"1到100的求和: {result}")

# 测试常用库
try:
    import numpy as np
    print(f"NumPy 版本: {np.__version__}")
except ImportError:
    print("⚠️ NumPy 未安装")

try:
    import matplotlib
    print(f"Matplotlib 版本: {matplotlib.__version__}")
except ImportError:
    print("⚠️ Matplotlib 未安装")

print("\n🎉 测试完成！")
